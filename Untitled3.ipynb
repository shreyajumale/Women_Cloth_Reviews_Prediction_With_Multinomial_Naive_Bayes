# %% [markdown]
# **Women Cloth Reviews Prediction with Multi Nomial Naive Bayes**

# %% [markdown]
# The multinomial Naive Bayes classifier is suitable for calssification with discrete features (e.g.,word counts for text classification). The multinomial distribution normally requires integer features counts. However, in practice, fractional counts such as tf-idf may also work.

# %% [markdown]
# **Import Dataset**

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# **Import Dataset**

# %%
df = pd.read_csv('https://github.com/shreyajumale/Women_Cloth_Reviews_Prediction_With_Multinomial_Naive_Bayes')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-2a12b6654e08> in <cell line: 1>()
# ----> 1 df = pd.read_csv('https://github.com/shreyajumale/Women_Cloth_Reviews_Prediction_With_Multinomial_Naive_Bayes')
#
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c42a15b2c7cf> in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# Example dataset
data = {
    'review': [
        'I love this dress, it fits perfectly!',
        'The material is cheap and not as described.',
        'Great value for money, very satisfied.',
        'The fit was awful and the color was off.',
        'Excellent quality, will buy again!'
    ],
    'label': ['positive', 'negative', 'positive', 'negative', 'positive']
}

df = pd.DataFrame(data)

# Split data into features and labels
X = df['review']
y = df['label']

# Vectorize the text data
vectorizer = TfidfVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.3, random_state=42)

# Train the Multinomial Naive Bayes classifier
model = MultinomialNB()
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
print(classification_report(y_test, y_pred))

# Predict new reviews
new_reviews = [
    'This blouse is beautiful and fits well.',
    'I am disappointed with the quality of the fabric.'
]
new_reviews_vectorized = vectorizer.transform(new_reviews)
predictions = model.predict(new_reviews_vectorized)
print(predictions)
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
#
# ['positive' 'positive']
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
